# %% [markdown]
# <a href="https://colab.research.google.com/github/alyssanew/CS2A_Alcantara/blob/main/2A_Alcantara_Exer4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Data Exploration

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('Lesson_4_student_grades_dataset.csv')
print(data.head())
# Out:
#    Hours_of_Study  Attendance_Percentage  Previous_Exam_Scores  \
# 0        4.370861              75.553988             63.085284
# 1        9.556429              86.257028             62.348940
# 2        7.587945              96.188375             95.312729
# 3        6.387926              91.966747             62.477310
# 4        2.404168              94.196834             63.597486
#
#    Extracurricular_Activities  Travel_Time_to_School     Grades
# 0                           0              24.325977  31.494329
# 1                           0              50.132016  43.250150
# 2                           0              59.861895  30.155663
# 3                           1              11.501300  39.617522
# 4                           0              54.868293  33.175874

# %% [markdown]
# Each features have impact to the the grades of the students. For example, if there are data that are missing or it is low, it will affect the overall grades of the student because it is required or included for the computation of the grades

# %% [markdown]
# 2. Data Processing

# %%
print(data.isnull().sum())
# Out:
# Hours_of_Study                0
# Attendance_Percentage         0
# Previous_Exam_Scores          0
# Extracurricular_Activities    0
# Travel_Time_to_School         0
# Grades                        0
# dtype: int64

# %% [markdown]
# It is important because with the use of it, we are able to see the data, and know if there are any missing datas. Also, if the data is in standard and by category, it is easier for us to track the data.

# %% [markdown]
# 3. Train-Test Split

# %%
x = data.drop('Grades', axis=1)
y = data['Grades']
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)
# Out:
# LinearRegression()

# %% [markdown]
# 4. Linear Regression Model

# %%
a = data[['Hours_of_Study']]
b = data['Grades']

model = LinearRegression()
model.fit(a,b)

plt.scatter(a,b)
plt.plot(a,model.predict(a),color='orange')
plt.xlabel('Hours_of_Study')
plt.title('Linear Regression')
plt.show()

new_a = [[np.random.randint(100,200)]]
predicted_a = model.predict(new_a)
print("new X", new_x)
print("Predicted Y for new A:", predicted_y)
# Out:
# new X [[175]]
# Predicted Y for new A: [89.07848362]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
c = data[['Attendance_Percentage']]
d = data['Grades']

model = LinearRegression()
model.fit(c,d)

plt.scatter(c,d)
plt.plot(c,model.predict(c),color='black')
plt.xlabel('Attendance_Percentage')
plt.title('Linear Regression')
plt.show()

new_c = [[np.random.randint(100,200)]]
predicted_c = model.predict(new_c)
print("new X", new_x)
print("Predicted Y for new C:", predicted_y)
# Out:
# new X [[175]]
# Predicted Y for new C: [89.07848362]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
e = data[['Previous_Exam_Scores']]
f = data['Grades']

model = LinearRegression()
model.fit(e,f)

plt.scatter(e,f)
plt.plot(e,model.predict(e),color='orange')
plt.xlabel('Previous Exam Scores')
plt.title('Linear Regression')
plt.show()

new_e = [[np.random.randint(100,200)]]
predicted_e = model.predict(new_e)
print("new X", new_x)
print("Predicted Y for new E:", predicted_y)
# Out:
# new X [[175]]
# Predicted Y for new E: [89.07848362]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
g = data[['Extracurricular_Activities']]
h = data['Grades']

model = LinearRegression()
model.fit(g,h)

plt.scatter(g,h)
plt.plot(g,model.predict(g),color='pink')
plt.xlabel('Extracurricular Activities')
plt.title('Linear Regression')
plt.show()

new_g = [[np.random.randint(100,200)]]
predicted_g = model.predict(new_g)
print("new X", new_x)
print("Predicted Y for new G:", predicted_y)
# Out:
# new X [[175]]
# Predicted Y for new G: [89.07848362]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
i = data[['Travel_Time_to_School']]
j = data['Grades']

model = LinearRegression()
model.fit(i,j)

plt.scatter(i,j)
plt.plot(i,model.predict(i),color='violet')
plt.xlabel('Travel Time to School')
plt.title('Linear Regression')
plt.show()

new_i = [[np.random.randint(100,200)]]
predicted_i = model.predict(new_i)
print("new X", new_x)
print("Predicted Y for new I:", predicted_y)
# Out:
# new X [[175]]
# Predicted Y for new I: [89.07848362]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# *   Import Libraries
# *   Import CSV
# *   Visualizing the Data
# *   Preparing for Data Modeling
# *   Fitting the Linear Regression Model
# *   Getting the Model Coefficient
# *   Visualizing the Linear Regression
# *   Making Predictions
#
#
#
#
#
#
#
# As the value increase, the grades of the students also increase and vice versa.

# %% [markdown]
# 5. Model Training

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# 7. Feature Importance Analysis

# %% [markdown]
# Each features has it's importance for predicting the students grade. For example, as longer as the students studies, the higher their grades.

# %% [markdown]
# 8. Discussion

# %% [markdown]
# The students previous exams scores shows a significant factor to their grades. It has a huge impact although it is just a one feature. It can significantly affect their grades

# %% [markdown]
# 9. Scenario Extension

# %% [markdown]
# The extracurricular activities is also one of the factor, in the data given to us, there are almost none extra activities. The students may be good at sports and other activities but not that excellent in academics. so the extra curricular activities may add up to their grades.

# %% [markdown]
# 10.Reflection

# %% [markdown]
# My reflection is, going to school is not enough. We have to be mindfully present and participate in class in order to achieve a good grades and to gain knowledge. We cannot just focus on one thing. We should give importance to all of it.
